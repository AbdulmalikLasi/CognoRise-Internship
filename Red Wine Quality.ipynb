# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
wine=pd.read_csv(r"C:\Users\Abdulmalik Lasisi\Downloads\winequality-red.csv")

# %%
wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
wine.shape
# Out:
# (1599, 12)

# %%
wine["quality"]=wine["quality"].astype(object)

# %%
wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   object
# dtypes: float64(11), object(1)
# memory usage: 150.0+ KB

# %%
def numerical_univariate_analysis(numerical_data):
    for col_name in numerical_data:
        print("*"*10, col_name, "*"*10)
        print(numerical_data[col_name].agg(['count', 'min', 'max', 'mean', 'median', 'std', 'skew']))
        print()

# %%
numerical_df =wine.select_dtypes(include=['float64','int64'])
numerical_univariate_analysis(numerical_df)
# Out:
# ********** fixed acidity **********
# count     1599.000000
# min          4.600000
# max         15.900000
# mean         8.319637
# median       7.900000
# std          1.741096
# skew         0.982751
# Name: fixed acidity, dtype: float64
#
# ********** volatile acidity **********
# count     1599.000000
# min          0.120000
# max          1.580000
# mean         0.527821
# median       0.520000
# std          0.179060
# skew         0.671593
# Name: volatile acidity, dtype: float64
#
# ********** citric acid **********
# count     1599.000000
# min          0.000000
# max          1.000000
# mean         0.270976
# median       0.260000
# std          0.194801
# skew         0.318337
# Name: citric acid, dtype: float64
#
# ********** residual sugar **********
# count     1599.000000
# min          0.900000
# max         15.500000
# mean         2.538806
# median       2.200000
# std          1.409928
# skew         4.540655
# Name: residual sugar, dtype: float64
#
# ...

# %%
wine["density"].value_counts()
# Out:
# density
# 0.99720    36
# 0.99680    35
# 0.99760    35
# 0.99800    29
# 0.99620    28
#            ..
# 0.99684     1
# 0.99764     1
# 0.99473     1
# 0.99320     1
# 0.99651     1
# Name: count, Length: 436, dtype: int64

# %%
wine["pH"].value_counts()
# Out:
# pH
# 3.30    57
# 3.36    56
# 3.26    53
# 3.38    48
# 3.39    48
#         ..
# 3.75     1
# 2.74     1
# 3.70     1
# 3.85     1
# 2.90     1
# Name: count, Length: 89, dtype: int64

# %%
fig, axs = plt.subplots(1, 5, figsize=(10, 3), constrained_layout=True)

sns.boxplot(data=wine, x="quality", y="fixed acidity", ax=axs[0])
sns.boxplot(data=wine, x="quality", y="volatile acidity", ax=axs[1])
sns.boxplot(data=wine, x="quality", y="density", ax=axs[2])
sns.boxplot(data=wine, x="quality", y="residual sugar", ax=axs[3])
sns.boxplot(data=wine, x="quality", y="pH", ax=axs[4])
# Out:
# <Axes: xlabel='quality', ylabel='pH'>

# %%
fig,axs = plt.subplots(1,2,figsize=(13,3),layout="constrained")
sns.countplot(data=wine,x='quality',ax=axs[0])
p=wine["quality"].value_counts()
axs[1].pie(p.values,labels=p.index,autopct="%1.1f%%")
plt.show()
